# %%
import os
import cv2
import numpy as np
from pathlib import Path
from PIL import Image
from tqdm import tqdm
from Yolo2UNet_dataset import yolo_to_unet_masks

inputImages = "Dataset/images/val" 
Outputmasks = os.makedirs("Dataset_unet/validation_masks", exist_ok=True)
Yololabels = "Dataset/labels/val"
# -----------------------------
# Example usage
# -----------------------------
yolo_to_unet_masks(
    images_dir=inputImages,
    labels_dir=Yololabels,
    output_dir=Outputmasks,
    single_class=True,  # True for tree/non-tree
    visualize=True      # preview mask
)
# Out:
# ...
# 100%|██████████| 8/8 [00:03<00:00,  2.53it/s]
